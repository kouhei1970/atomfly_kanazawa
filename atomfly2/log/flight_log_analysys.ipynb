# %%
import numpy as np
import matplotlib.pyplot as plt

data=np.loadtxt('log00.log')#, delimiter=',', skiprows=1)

t=data.T[0]
Wp=data.T[1]
Wq=data.T[2]
Wr=data.T[3]
Ax=data.T[4]
Ay=data.T[5]
Az=data.T[6]

Pref=data.T[7]
Qref=data.T[8]
Rref=data.T[9]

phi=data.T[10]
theta=data.T[11]
psi=data.T[12]

phi_ref=data.T[13]
theta_ref=data.T[14]
psi_ref=data.T[15]

Pcom=data.T[16]
Qcom=data.T[17]
Rcom=data.T[18]

pfilter=data.T[19]
qfilter=data.T[20]
rfilter=data.T[21]

phi_filter=data.T[22]
theta_filter=data.T[23]

Pbias=data.T[24]
Qbias=data.T[25]
Rbias=data.T[26]

Tref=data.T[27]
Acc_norm=data.T[28]

# %%
tmin=0
tmax=max(t)
ax1=plt.figure(figsize=(16,16))
ax1.add_subplot(611)
#plt.figure(figsize=(16,4))
plt.plot(t,phi*180/np.pi,label='phi')
plt.plot(t,theta*180/np.pi,label='theta')
plt.plot(t,psi*180/np.pi,label='psi')
plt.legend()
plt.ylabel('Angle[deg]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-50,50])
plt.grid()

ax1.add_subplot(612)
#plt.figure(figsize=(16,4))
plt.plot(t,phi_ref*180/np.pi,label='phi')
plt.plot(t,theta_ref*180/np.pi,label='theta')
plt.plot(t,psi_ref*180/np.pi,label='psi')
plt.legend()
plt.ylabel('Angle[deg]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-50,50])
plt.grid()


ax1.add_subplot(613)
#plt.figure(figsize=(16,4))
plt.plot(t,(Wp)*180/np.pi,label='p')
plt.plot(t,(Wq)*180/np.pi,label='q')
plt.plot(t,(Wr)*180/np.pi,label='r')
plt.legend()
plt.ylabel('Angle rate[deg/s]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-90,90])
plt.grid()

ax1.add_subplot(614)
#plt.figure(figsize=(16,4))
plt.plot(t,(Pref)*180/np.pi,label='pref')
plt.plot(t,(Qref)*180/np.pi,label='qref')
plt.plot(t,(Rref)*180/np.pi,label='rref')
plt.legend()
plt.ylabel('Angle rate[deg/s]')
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-90,90])
plt.grid()

ax1.add_subplot(615)
#plt.figure(figsize=(16,4))
plt.plot(t,Ax,label='ax')
plt.plot(t,Ay,label='ay')
plt.plot(t,Az,label='az')
plt.legend()
#plt.xlim([0,max(t)])
plt.xlim([tmin,tmax])
#plt.xlim([10,10.1])
#plt.yticks([-180,-135,-90,-45,0,45,90,135,180])
#plt.ylim([-50,50])
plt.ylabel('Acceleration[m/s^2]')
plt.grid()
plt.xlabel('Time[s]')




plt.show()

# %%
tmin=0
tmax=12

ax1=plt.figure(figsize=(20,12))
ax1.add_subplot(321)
plt.plot(t,Wp-Pbias,label='p')
plt.plot(t,p_ref,label='p_ref')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.0,1.0])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,Wq-Qbias,label='q')
plt.plot(t,q_ref,label='q_ref')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,Wr-Rbias,label='r')
plt.plot(t,r_ref,label='r_ref')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi,label='phi')
plt.plot(t,phi_ref,label='phi_ref')
plt.legend()
plt.ylabel('Roll angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta,label='theta')
plt.plot(t,theta_ref,label='theta_ref')
plt.legend()
plt.ylabel('Pitch angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1.add_subplot(326)
plt.plot(t,psi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()
plt.show()

ax1a=plt.figure(figsize=(20,12))
ax1a.add_subplot(321)
plt.plot(t,p_ref-(Wp-Pbias),label='p_err')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.0,1.0])
plt.grid()

ax1a.add_subplot(323)
plt.plot(t,q_ref-(Wq-Qbias),label='q_err')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1a.add_subplot(325)
plt.plot(t,r_ref-(Wr-Rbias),label='r_err')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1a.add_subplot(322)
plt.plot(t,phi_ref-phi,label='phi_err')
plt.legend()
plt.ylabel('Roll angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1a.add_subplot(324)
plt.plot(t,theta_ref-theta,label='theta_err')
plt.legend()
plt.ylabel('Pitch angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1a.add_subplot(326)
plt.plot(t,psi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()
plt.show()



ax2=plt.figure(figsize=(16,8))
ax2.add_subplot(421)
plt.plot(t,T_ref/11.1,label='T_ref')
plt.plot([0,max(t)],[0.1, 0.1])
plt.plot([0,max(t)],[0.16, 0.18])
plt.legend()
plt.ylabel('T_ref')
plt.xlim([tmin,tmax])
plt.ylim([0,1.1])
plt.grid()

ax2.add_subplot(422)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Pcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(423)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Qcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(424)
plt.plot(t,Rcom,label='Rcom')
plt.legend()
plt.ylabel('Rcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

fr=(T_ref+(-Pcom +Qcom +Rcom)*0.25)*0.0901
fl=(T_ref+( Pcom +Qcom -Rcom)*0.25)*0.0901
rr=(T_ref+(-Pcom -Qcom -Rcom)*0.25)*0.0901
rl=(T_ref+( Pcom -Qcom +Rcom)*0.25)*0.0901

ax2.add_subplot(425)
plt.plot(t,fl,label='FL_duty')
plt.legend()
plt.ylabel('FL_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

ax2.add_subplot(426)
plt.plot(t,fr,label='FR_duty')
plt.legend()
plt.ylabel('FR_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

ax2.add_subplot(427)
plt.plot(t,rl,label='RL_duty')
plt.legend()
plt.ylabel('RL_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

ax2.add_subplot(428)
plt.plot(t,rr,label='RR_duty')
plt.legend()
plt.ylabel('RR_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

plt.show()


ax3=plt.figure(figsize=(16,8))
ax3.add_subplot(321)
plt.plot(t,pd,label='pd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(323)
plt.plot(t,qd,label='qd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(325)
plt.plot(t,rd,label='rd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(322)
plt.plot(t,phid,label='phid')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(324)
plt.plot(t,thetad,label='thetad')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()
plt.show()

ax4=plt.figure(figsize=(16,9))
ax4.add_subplot(211)
plt.plot(t[:],(np.sqrt(Ax**2+Ay**2+Az**2))[:],'-')
plt.plot(t[:],Acc_norm[:],'-')
plt.grid()
ax4.add_subplot(212)
plt.plot(t[:],(np.sqrt(Wp**2+Wq**2+Wr**2))[:],'-')
plt.grid()
plt.show()

ax5=plt.figure(figsize=(16,9))
ax5.add_subplot(311)
psum=0.01*(Wp-Pbias).cumsum()
plt.plot(t,psum*180/np.pi)
plt.plot(t,phi*180/np.pi)
plt.grid()
ax5.add_subplot(312)
qsum=0.01*(Wq-Qbias).cumsum()
plt.plot(t,qsum*180/np.pi)
plt.plot(t,theta*180/np.pi)
plt.grid()
ax5.add_subplot(313)
rsum=0.01*(Wr-Rbias).cumsum()
plt.plot(t,rsum*180/np.pi)
plt.plot(t,psi*180/np.pi)
plt.grid()
plt.show()

# %%
tmin=0
tmax=12

ax1=plt.figure(figsize=(20,12))
ax1.add_subplot(321)
plt.plot(t,p_ref-(Wp-Pbias),label='p_err')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.0,1.0])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,q_ref-(Wq-Qbias),label='q_err')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,r_ref-(Wr-Rbias),label='r_err')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi,label='phi')
plt.plot(t,phi_ref,label='phi_ref')
plt.legend()
plt.ylabel('Roll angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta,label='theta')
plt.plot(t,theta_ref,label='theta_ref')
plt.legend()
plt.ylabel('Pitch angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1.add_subplot(326)
plt.plot(t,psi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()
plt.show()

ax1a=plt.figure(figsize=(20,12))
ax1a.add_subplot(321)
plt.plot(t,Wp-Pbias,label='p')
plt.plot(t,p_ref,label='p_ref')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.0,1.0])
plt.grid()

ax1a.add_subplot(323)
plt.plot(t,Wq-Qbias,label='q')
plt.plot(t,q_ref,label='q_ref')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1a.add_subplot(325)
plt.plot(t,Wr-Rbias,label='r')
plt.plot(t,r_ref,label='r_ref')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.,1.])
plt.grid()

ax1a.add_subplot(322)
plt.plot(t,phi_ref-phi,label='phi_err')
plt.legend()
plt.ylabel('Roll angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1a.add_subplot(324)
plt.plot(t,theta_ref-theta,label='theta_err')
plt.legend()
plt.ylabel('Pitch angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()

ax1a.add_subplot(326)
plt.plot(t,psi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[rad]')
plt.xlim([tmin,tmax])
plt.ylim([-0.3,0.3])
plt.grid()
plt.show()



ax2=plt.figure(figsize=(16,8))
ax2.add_subplot(421)
plt.plot(t,T_ref/11.1,label='T_ref')
plt.plot([0,max(t)],[0.1, 0.1])
plt.plot([0,max(t)],[0.18, 0.18])
plt.legend()
plt.ylabel('T_ref')
plt.xlim([tmin,tmax])
plt.ylim([0,1.1])
plt.grid()

ax2.add_subplot(422)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Pcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(423)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Qcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(424)
plt.plot(t,Rcom,label='Rcom')
plt.legend()
plt.ylabel('Rcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

fr=(T_ref+(-Pcom +Qcom +Rcom)*0.25)*0.0901
fl=(T_ref+( Pcom +Qcom -Rcom)*0.25)*0.0901
rr=(T_ref+(-Pcom -Qcom -Rcom)*0.25)*0.0901
rl=(T_ref+( Pcom -Qcom +Rcom)*0.25)*0.0901

ax2.add_subplot(425)
plt.plot(t,fl,label='FL_duty')
plt.legend()
plt.ylabel('FL_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

ax2.add_subplot(426)
plt.plot(t,fr,label='FR_duty')
plt.legend()
plt.ylabel('FR_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

ax2.add_subplot(427)
plt.plot(t,rl,label='RL_duty')
plt.legend()
plt.ylabel('RL_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

ax2.add_subplot(428)
plt.plot(t,rr,label='RR_duty')
plt.legend()
plt.ylabel('RR_duty')
plt.xlim([tmin,tmax])
#plt.ylim([0,1.5])
plt.grid()

plt.show()


ax3=plt.figure(figsize=(16,8))
ax3.add_subplot(321)
plt.plot(t,pd,label='pd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(323)
plt.plot(t,qd,label='qd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(325)
plt.plot(t,rd,label='rd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(322)
plt.plot(t,phid,label='phid')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(324)
plt.plot(t,thetad,label='thetad')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()
plt.show()

ax4=plt.figure(figsize=(16,9))
ax4.add_subplot(211)
plt.plot(t[:],(np.sqrt(Ax**2+Ay**2+Az**2))[:],'-')
plt.plot(t[:],Acc_norm[:],'-')
plt.grid()
ax4.add_subplot(212)
plt.plot(t[:],(np.sqrt(Wp**2+Wq**2+Wr**2))[:],'-')
plt.grid()
plt.show()

ax5=plt.figure(figsize=(16,9))
ax5.add_subplot(311)
psum=0.01*(Wp-Pbias).cumsum()
plt.plot(t,psum*180/np.pi)
plt.plot(t,phi*180/np.pi)
plt.grid()
ax5.add_subplot(312)
qsum=0.01*(Wq-Qbias).cumsum()
plt.plot(t,qsum*180/np.pi)
plt.plot(t,theta*180/np.pi)
plt.grid()
ax5.add_subplot(313)
rsum=0.01*(Wr-Rbias).cumsum()
plt.plot(t,rsum*180/np.pi)
plt.plot(t,psi*180/np.pi)
plt.grid()
plt.show()

# %%
tmin=0
tmax=12
ax1=plt.figure(figsize=(16,9))

ax1.add_subplot(321)
plt.plot(t,Wp-Pbias,label='p')
plt.plot(t,p_ref,label='p_ref')
plt.legend()
plt.ylabel('Roll rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1.5,1.5])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,Wq-Qbias,label='q')
plt.plot(t,q_ref,label='q_ref')
plt.legend()
plt.ylabel('Pitch rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-1,1])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,Wr-Rbias,label='r')
plt.plot(t,r_ref,label='r_ref')
plt.legend()
plt.ylabel('Yaw rate[rad/s]')
plt.xlim([tmin,tmax])
plt.ylim([-0.5,0.5])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi_ref-phi,label='phi_err')
#plt.plot(t,phi_ref,label='phi_ref')
plt.legend()
plt.ylabel('Roll error angle[rad]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta_ref-theta,label='theta_err')
#plt.plot(t,theta_ref,label='theta_ref')
plt.legend()
plt.ylabel('Pitch error angle[rad]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()
plt.show()

ax2=plt.figure(figsize=(16,5))
ax2.add_subplot(321)
plt.plot(t,Pcom,label='Pcom')
plt.legend()
plt.ylabel('Pcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(323)
plt.plot(t,Qcom,label='Qcom')
plt.legend()
plt.ylabel('Qcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

ax2.add_subplot(325)
plt.plot(t,Rcom,label='Rcom')
plt.legend()
plt.ylabel('Rcom')
plt.xlim([tmin,tmax])
#plt.ylim([-12,12])
plt.grid()

plt.show()


ax3=plt.figure(figsize=(16,8))
ax3.add_subplot(321)
plt.plot(t,pd,label='pd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(323)
plt.plot(t,qd,label='qd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(325)
plt.plot(t,rd,label='rd')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(322)
plt.plot(t,phid,label='phid')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()

ax3.add_subplot(324)
plt.plot(t,thetad,label='thetad')
plt.grid()
plt.xlim([tmin,tmax])
plt.legend()



plt.show()

# %%
h=0.0025
T=0.0075
err=p_ref-Wp
derr=(err[1:]-err[0:-1])/h


Y=[]
y=0
for x in derr:    
    y=y*T/(T+h)+x*h/(T+h)
    Y.append(y)
Y=np.array(Y)
#plt.figure(figsize=(16,9))
plt.plot(t[0:-1], derr)
plt.plot(t[0:-1], Y)
plt.plot(t,pd)
#plt.ylim(-50,50)
plt.xlim(5,8)
plt.grid()

# %%
h=0.01
T=0.01*3

err=phi_ref-phi
derr=(err[1:]-err[0:-1])/h

Y=[]
y=0
for x in derr:
    y=y*T/(T+h)+x*h/(T+h)
    Y.append(y)
Y=np.array(Y)
#plt.figure(figsize=(16,9))
plt.plot(t[0:-1], derr)
plt.plot(t[0:-1], Y)

#plt.ylim(-1,1)
plt.xlim(0,10)
plt.grid()

# %%
tmin=0
tmax=14
ax1=plt.figure(figsize=(16,9))

ax1.add_subplot(321)
plt.plot(t,Mx,label='mx')
plt.legend()
plt.ylabel('Mag x')
plt.xlim([tmin,tmax])
#plt.ylim([-1.5,1.5])
plt.grid()

ax1.add_subplot(323)
plt.plot(t,My,label='my')
plt.legend()
plt.ylabel('Mag y')
plt.xlim([tmin,tmax])
plt.ylim([-0.1,0.9])
plt.grid()

ax1.add_subplot(325)
plt.plot(t,Mz,label='mz')
plt.legend()
plt.ylabel('Mag z')
plt.xlim([tmin,tmax])
plt.ylim([0.85,1.0])
plt.grid()

ax1.add_subplot(322)
plt.plot(t,phi*180/np.pi,label='phi')
plt.plot(t,phi_ref*180/np.pi,label='phi_ref')
plt.legend()
plt.ylabel('Roll angle[deg]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(324)
plt.plot(t,theta*180/np.pi,label='theta')
plt.plot(t,theta_ref*180/np.pi,label='theta_ref')
plt.legend()
plt.ylabel('Pitch angle[deg]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()

ax1.add_subplot(326)
plt.plot(t,psi*180/np.pi,label='psi')
plt.legend()
plt.ylabel('Yaw angle[deg]')
plt.xlim([tmin,tmax])
#plt.ylim([-0.1,0.1])
plt.grid()
plt.show()

# %%
print(Mx[500:700].var())
print(My[500:700].var())
print(Mz[500:700].var())

# %%
print(Ax[500:700].var())
print(Ay[500:700].var())
print(Az[500:700].var())

# %%
print(Wp[500:700].var())
print(Wq[500:700].var())
print(Wr[500:700].var())

# %%
fr=(-Pcom +Qcom +Rcom)*0.25
fl=( Pcom +Qcom -Rcom)*0.25
rr=(-Pcom -Qcom -Rcom)*0.25
rl=( Pcom -Qcom +Rcom)*0.25

plt.plot(t,fr,label='fr')
plt.legend()
plt.grid()
plt.show()
plt.plot(t,fl,label='fl')
plt.legend()
plt.grid()
plt.show()
plt.plot(t,rr,label='rr')
plt.legend()
plt.grid()
plt.show()
plt.plot(t,rl,label='rl')
plt.legend()
plt.grid()
plt.show()

# %%
phi_ref

# %%
theta_ref

# %%
psi_ref

# %%
T_ref[590:600]

# %%
2.19/11.1

# %%
ax=plt.figure(figsize=(16,9))
ax.add_subplot(211)
plt.plot(t[:],(np.sqrt(Ax**2+Ay**2+Az**2))[:],'-')
plt.plot(t[:],Acc_norm[:],'-')

plt.grid()

ax.add_subplot(212)
plt.plot(t[:],(np.sqrt(Wp**2+Wq**2+Wr**2))[:],'-')
plt.grid()

plt.show()

# %%
print(phi_ref[:50].mean())
print(theta_ref[:50].mean())
print(r_ref[:50].mean())

# %%
r_ref
